# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from math import pi,sqrt,cos,sin
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

#the gravitational constant
g = 1

m1 = 1
m2 = 1.2

G = 1

# %%
def gravity(r,t):
    x = r[0]
    vx = r[1]
    y = r[2]
    vy = r[3]
    
    dxdt = vx
    dydt = vy
    
    dvxdt = -G*(m1+m2)*(x)/((x**2+y**2)**(3/2))

    dvydt = -G*(m1+m2)*(y)/((x**2+y**2)**(3/2))
    #x-position x-velocity y-position y-velocity
    ##################
    drdt = [dxdt,dvxdt,dydt,dvydt]

    return drdt

# %%
#orbit 1
#initial condition
i0 = [-1, 0.2, -1.2, -0.3]  

k = 15
t = np.linspace(0,10,2**k+1) 

ar = odeint(gravity,i0,t)

# %%
#bounded orbit inside     
fig, axl = plt.subplots(1,1,figsize=(8,8))

ax = ar[:,0]
ay = ar[:,2]

r1x = -m1/(m1+m2)*ax
r1y = -m1/(m1+m2)*ay

r2x = m2/(m1+m2)*ax
r2y = m2/(m1+m2)*ay
    
axl.plot(ax, ay, color='red', label='Relative Position')
axl.plot(r1x, r1y, color='blue', label='Position of Mass 1')
axl.plot(r2x, r2y, color='green', label='Position of Mass 2')

#the axis control function
axl.set_ylim(-1.5,1.5)
axl.set_xlim(-1.5,1.5)

axl.spines['left'].set_position('zero')
    
axl.spines['right'].set_color('none')
axl.spines['bottom'].set_position('zero')
axl.spines['top'].set_color('none')
axl.xaxis.set_minor_locator(MultipleLocator(0.05))
axl.yaxis.set_minor_locator(MultipleLocator(0.05))
axl.xaxis.set_tick_params(labelsize=10)
axl.yaxis.set_tick_params(labelsize=10)
axl.set_ylabel('y', fontsize=15)
axl.set_xlabel('x', fontsize=15)
axl.xaxis.set_label_coords(0.925, 0.475)
axl.yaxis.set_label_coords(0.475, 0.925)
axl.set_title('Elliptical Orbits 1 of the Masses',fontsize=20)
axl.legend(fontsize=12,loc='upper right')

# %%
#orbit 2
#initial condition
i0 = [1.1, 0.63, 1.2, -0.63]  

k = 15
t = np.linspace(0,10,2**k+1) 

ar = odeint(gravity,i0,t)

# %%
#bounded orbit inside     
fig, axl = plt.subplots(1,1,figsize=(8,8))

ax = ar[:,0]
ay = ar[:,2]

r1x = -m1/(m1+m2)*ax
r1y = -m1/(m1+m2)*ay

r2x = m2/(m1+m2)*ax
r2y = m2/(m1+m2)*ay
    
axl.plot(ax, ay, color='red', label='Relative Position')
axl.plot(r1x, r1y, color='blue', label='Position of Mass 1')
axl.plot(r2x, r2y, color='green', label='Position of Mass 2')

#the axis control function
axl.set_ylim(-2,2)
axl.set_xlim(-2,2)

axl.spines['left'].set_position('zero')
    
axl.spines['right'].set_color('none')
axl.spines['bottom'].set_position('zero')
axl.spines['top'].set_color('none')
axl.xaxis.set_tick_params(labelsize=10)
axl.yaxis.set_tick_params(labelsize=10)
axl.set_ylabel('y', fontsize=15)
axl.set_xlabel('x', fontsize=15)
axl.xaxis.set_label_coords(0.925, 0.475)
axl.yaxis.set_label_coords(0.475, 0.925)
axl.set_title('Elliptical Orbits 2 of the Masses',fontsize=20)
axl.legend(fontsize=12,loc='upper left')

# %%
#orbit 3
#initial condition
i0 = [-20.6, 0.7, -20, 0.9]  

k = 15
t = np.linspace(0,150,2**k+1) 

ar = odeint(gravity,i0,t)

# %%
#bounded orbit inside     
fig, axl = plt.subplots(1,1,figsize=(8,8))

ax = ar[:,0]
ay = ar[:,2]

r1x = -m1/(m1+m2)*ax
r1y = -m1/(m1+m2)*ay

r2x = m2/(m1+m2)*ax
r2y = m2/(m1+m2)*ay
    
axl.plot(ax, ay, color='red', label='Relative Position')
axl.plot(r1x, r1y, color='blue', label='Position of Mass 1')
axl.plot(r2x, r2y, color='green', label='Position of Mass 2')

#the axis control function
axl.set_ylim(-10,10)
axl.set_xlim(-60,60)

axl.spines['left'].set_position('zero')
    
axl.spines['right'].set_color('none')
axl.spines['bottom'].set_position('zero')
axl.spines['top'].set_color('none')
axl.xaxis.set_tick_params(labelsize=10)
axl.yaxis.set_tick_params(labelsize=10)
axl.set_ylabel('y', fontsize=15)
axl.set_xlabel('x', fontsize=15)
axl.xaxis.set_label_coords(0.925, 0.475)
axl.yaxis.set_label_coords(0.475, 0.925)
axl.set_title('Hyperbolic Paths of the Masses',fontsize=20)
axl.legend(fontsize=12,loc='upper left')

# %%
#orbit 4
#initial condition
i0 = [-11, 0.37, -13.2387, 0.31]  

k = 15
t = np.linspace(0,1000,2**k+1) 

ar = odeint(gravity,i0,t)

# %%
#bounded orbit inside     
fig, axl = plt.subplots(1,1,figsize=(8,8))

ax = ar[:,0]
ay = ar[:,2]

r1x = -m1/(m1+m2)*ax
r1y = -m1/(m1+m2)*ay

r2x = r1x + ax
r2y = r1y + ay
    
axl.plot(ax, ay, color='red')
axl.plot(r1x, r1y, color='blue')
axl.plot(r2x, r2y, color='green')

#the axis control function

axl.spines['left'].set_position('zero')
    
axl.spines['right'].set_color('none')
axl.spines['bottom'].set_position('zero')
axl.spines['top'].set_color('none')
axl.xaxis.set_tick_params(labelsize=10)
axl.yaxis.set_tick_params(labelsize=10)
axl.set_ylabel('y', fontsize=20)
axl.set_xlabel('x', fontsize=20)
axl.xaxis.set_label_coords(0.8, 0.475)
axl.yaxis.set_label_coords(0.425, 0.8)
axl.set_title('Bounded Orbit Inside Planet',fontsize=20)
axl.legend(fontsize=18,loc='upper right')
# Out:
# /var/folders/q4/sy6ht9gn2k7cc77fvf4fb9pw0000gn/T/ipykernel_79938/1265432746.py:31: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axl.legend(fontsize=18,loc='upper right')
